# %%
import os
os.chdir('../')
# %pwd
# Out:
# 'c:\\Users\\EI13136\\Documents\\mlops'

# %%
import pandas as pd
from sklearn.metrics import precision_score, recall_score, accuracy_score, roc_auc_score

# %%
test_df = pd.read_csv("artifacts/data_transformation/test.csv")
valid_df = pd.read_csv("artifacts/data_transformation/valid.csv")

# %%
x_test = test_df.drop(columns='Satisfaction')
y_test = test_df['Satisfaction']

x_valid = valid_df.drop(columns='Satisfaction')
y_valid = valid_df['Satisfaction']

# %%
def model_evaluation(y_true, y_pred):
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    acc_score = accuracy_score(y_true, y_pred)
    roc_auc = roc_auc_score(y_true, y_pred)
    #conf_matrix = confusion_matrix(y_true, y_pred)
    #f1 = f1_score(y_true, y_pred)
    print("  {:.2%}\t  {:.2%}\t  {:.2%}\t\t{:.2%}".format(precision, recall, roc_auc, acc_score))
    # print("Confusion Matrix:")
    # print(conf_matrix)
    return acc_score

# %%
import joblib
from airline_passenger_satisfaction.logger import logger

model_directory = 'artifacts/model_trainer'
model_list = []
accuracy_score_list = []

for model_file in os.listdir(model_directory):
    if model_file.endswith('.joblib'):
        model_path = os.path.join(model_directory, model_file)
        model = joblib.load(model_path)

        y_test_pred = model.predict(x_test)
        y_valid_pred = model.predict(x_valid)

        print(f"{'>'*5} {model_file.replace('.joblib','')} {'<'*5}".center(64, ' '), '\n')
        print("*** Test Dataset ***".center(64, ' '))
        print(" Precision ", " Recall ", " ROC-AUC Score ", "  Accuracy Score ", sep='\t')
        print('-' * 64)
        acc_score = model_evaluation(y_test, y_test_pred)

        print("*** Validation Dataset ***".center(64, ' '))
        print(" Precision ", " Recall ", " ROC-AUC Score ", "  Accuracy Score ", sep='\t')
        print('-' * 64)
        model_evaluation(y_test, y_test_pred)

        model_list.append(model_file.replace('.joblib',''))
        accuracy_score_list.append(acc_score)


best_model_index = accuracy_score_list.index(max(accuracy_score_list))
best_model_name = model_list[best_model_index].replace('.joblib','')
best_model_score = accuracy_score_list[best_model_index]

print("Model :", best_model_name, "Accuracy Score :", "{0:.2%}".format(best_model_score))

if best_model_score > 0.6:
    joblib.dump(best_model_name, 'best_model.joblib')
    print(f"Best model : {best_model_name} saved as 'best_model'.joblib")
else:
    print("No model with accuracy score > 60% found. Skipping saving.")
# Out:
#                  >>>>> Adaboost Classifier <<<<<
#
#                       *** Test Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   91.97%	  90.98%	  92.46%		92.66%
#                    *** Validation Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   91.97%	  90.98%	  92.46%		92.66%
#
#                       >>>>> best_model <<<<<
#
#                       *** Test Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   97.53%	  94.17%	  96.18%		96.45%
#                    *** Validation Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   97.53%	  94.17%	  96.18%		96.45%
#
#                >>>>> Decision Tree Classifier <<<<<
#
#                       *** Test Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   93.11%	  93.84%	  94.27%		94.33%
#                    *** Validation Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   93.11%	  93.84%	  94.27%		94.33%
#
#              >>>>> Gradient Boosting Classifier <<<<<
#
#                       *** Test Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   94.42%	  92.22%	  94.03%		94.28%
#                    *** Validation Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   94.42%	  92.22%	  94.03%		94.28%
#
#                    >>>>> Gradient Descent <<<<<
#
#                       *** Test Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   87.41%	  82.45%	  86.70%		87.27%
#                    *** Validation Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   87.41%	  82.45%	  86.70%		87.27%
#
#                 >>>>> KNeighbors Classifier <<<<<
#
#                       *** Test Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   94.48%	  88.76%	  92.40%		92.90%
#                    *** Validation Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   94.48%	  88.76%	  92.40%		92.90%
#
#                        >>>>> Lightgbm <<<<<
#
#                       *** Test Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   97.53%	  94.17%	  96.18%		96.45%
#                    *** Validation Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   97.53%	  94.17%	  96.18%		96.45%
#
#                  >>>>> Logistic Regression <<<<<
#
#                       *** Test Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   86.63%	  83.40%	  86.79%		87.25%
#                    *** Validation Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   86.63%	  83.40%	  86.79%		87.25%
#
#                      >>>>> Naive Bayes <<<<<
#
#                       *** Test Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   82.88%	  81.40%	  84.29%		84.68%
#                    *** Validation Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   82.88%	  81.40%	  84.29%		84.68%
#
#                >>>>> Random Forest Classifier <<<<<
#
#                       *** Test Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   96.96%	  94.13%	  95.94%		96.18%
#                    *** Validation Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   96.96%	  94.13%	  95.94%		96.18%
#
#                 >>>>> Support Vector Machine <<<<<
#
#                       *** Test Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   95.45%	  93.33%	  94.97%		95.19%
#                    *** Validation Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   95.45%	  93.33%	  94.97%		95.19%
#
#                   >>>>> Xgboost Classifier <<<<<
#
#                       *** Test Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   97.04%	  94.51%	  96.16%		96.38%
#                    *** Validation Dataset ***
#  Precision 	 Recall 	 ROC-AUC Score 	  Accuracy Score
# ----------------------------------------------------------------
#   97.04%	  94.51%	  96.16%		96.38%
# Model : best_model Accuracy Score : 96.45%
# Best model : best_model saved as 'best_model'.joblib

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class ModelEvaluationConfig:
    root_dir: Path
    test_data_path: Path
    valid_data_path: Path
    models_path: Path
    best_model_path: Path
    metrics_file_name: Path
    target_column: str

# %%
from airline_passenger_satisfaction.constants import *
from airline_passenger_satisfaction.utils.common import read_yaml, create_directories, save_json

# %%
class ConfigurationManager:
    def __init__(self,
                 config_filepath = CONFIG_FILE_PATH,
                 params_filepath = PARAMS_FILE_PATH,
                 schema_filepath = SCHEMA_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_model_evaluation(self)-> ModelEvaluationConfig:
        config = self.config.model_evaluation
        params = self.params
        schema = self.schema.TARGET_COLUMN

        create_directories([config.root_dir])

        model_evaluation_config = ModelEvaluationConfig(
            root_dir= config.root_dir,
            test_data_path= config.test_data_path,
            valid_data_path= config.valid_data_path,
            models_path= config.models_path,
            best_model_path= config.best_model_path,
            target_column= schema.name,
            metrics_file_name= config.metric_file_name,
        ) 

        return model_evaluation_config

# %%
from urllib.parse import urlparse
from pathlib import Path
import joblib
from airline_passenger_satisfaction.logger import logger
from airline_passenger_satisfaction.utils.common import model_evaluation

class ModelEvaluation:
    def __init__(self, config: ModelEvaluationConfig) -> None:
        self.config = config
    
    def identify_best_model(self):
        test_df = pd.read_csv(self.config.test_data_path)
        valid_df = pd.read_csv(self.config.valid_data_path)

        x_test = test_df.drop(columns= self.config.target_column)
        y_test = test_df[self.config.target_column]

        x_valid = valid_df.drop(columns=self.config.target_column)
        y_valid = valid_df[self.config.target_column]


        model_list = []
        accuracy_score_list = []

        for model_file in os.listdir(self.config.models_path):
            if model_file.endswith('.joblib'):
                model_path = Path(os.path.join(self.config.models_path, model_file))
                model = joblib.load(model_path)

                y_test_pred = model.predict(x_test)
                y_valid_pred = model.predict(x_valid)

                logger.info(f"{'>'*5} {model_file.replace('.joblib','')} {'<'*5}".center(64))
                logger.info("*** Test Dataset ***".center(64))
                logger.info(" Precision \t Recall \tROC-AUC Score \t  Accuracy Score ")
                logger.info('-' * 64)
                test_precision, test_recall, test_roc_auc, test_acc_score = model_evaluation(y_test, y_test_pred)
                logger.info(f" {test_precision:.2%}\t  {test_recall:.2%}\t  {test_roc_auc:.2%}\t\t {test_acc_score:.2%}")

                logger.info("*** Validation Dataset ***".center(64))
                logger.info(" Precision \t Recall \tROC-AUC Score \t  Accuracy Score ")
                logger.info('-' * 64)
                precision, recall, roc_auc, acc_score = model_evaluation(y_valid, y_valid_pred)
                logger.info(f" {precision:.2%}\t  {recall:.2%}\t  {roc_auc:.2%}\t\t {acc_score:.2%}"+'\n')
        
                model_list.append(model_file)
                avg_acc_score = (acc_score+test_acc_score)/2
                accuracy_score_list.append(avg_acc_score)

        best_model_index = accuracy_score_list.index(max(accuracy_score_list))
        best_model_name = model_list[best_model_index]
        best_model_score = accuracy_score_list[best_model_index]


        if best_model_score > 0.6:
            logger.info(f"Model: {best_model_name} with a best Accuracy Score : {best_model_score:.2%}")
            save_json(path=Path(self.config.metrics_file_name), data={"accuracy_score" :best_model_score})

            with open(f'{self.config.models_path}/best_model.txt', 'w') as file:
                file.write(f"Model : {best_model_name.replace('.joblib','')} with Accuracy Score: {best_model_score:.2%}") 
                logger.info(f"Best model: {best_model_name} saved as Best_model.joblib file format")
                model = joblib.load(f'{self.config.models_path}/{best_model_name}')
                joblib.dump(model, f'{self.config.models_path}/Best_model.joblib')
    

        else:
            logger.info("No model with accuracy score > 60% found. Skipping saving.")

# %%
import sys
from airline_passenger_satisfaction.exception import CustomException

try:
    config = ConfigurationManager()
    model_evaluation_config = config.get_model_evaluation()
    model_evaluation_config = ModelEvaluation(config=model_evaluation_config)
    model_evaluation_config.identify_best_model()
except Exception as e:
    raise CustomException(e,sys)
# Out:
# [2024-02-15 14:41:53,756] [INFO] [Airline Passenger Reviews Logger] [common] : yaml file config\config.yaml loaded successfully
# [2024-02-15 14:41:53,758] [INFO] [Airline Passenger Reviews Logger] [common] : yaml file params.yaml loaded successfully
# [2024-02-15 14:41:53,762] [INFO] [Airline Passenger Reviews Logger] [common] : yaml file schema.yaml loaded successfully
# [2024-02-15 14:41:53,763] [INFO] [Airline Passenger Reviews Logger] [common] : Created directory at : artifacts
# [2024-02-15 14:41:53,764] [INFO] [Airline Passenger Reviews Logger] [common] : Created directory at : artifacts/model_evaluation
# [2024-02-15 14:41:54,270] [INFO] [Airline Passenger Reviews Logger] [370800297] :                 >>>>> Adaboost Classifier <<<<<
# [2024-02-15 14:41:54,271] [INFO] [Airline Passenger Reviews Logger] [370800297] :                       *** Test Dataset ***
# [2024-02-15 14:41:54,271] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:54,272] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:54,300] [INFO] [Airline Passenger Reviews Logger] [370800297] :  91.97%	  90.98%	  92.46%		 92.66%
# [2024-02-15 14:41:54,301] [INFO] [Airline Passenger Reviews Logger] [370800297] :                    *** Validation Dataset ***
# [2024-02-15 14:41:54,301] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:54,302] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:54,322] [INFO] [Airline Passenger Reviews Logger] [370800297] :  92.13%	  90.65%	  92.35%		 92.57%
#
# [2024-02-15 14:41:54,423] [INFO] [Airline Passenger Reviews Logger] [370800297] :                      >>>>> Best_model <<<<<
# [2024-02-15 14:41:54,423] [INFO] [Airline Passenger Reviews Logger] [370800297] :                       *** Test Dataset ***
# [2024-02-15 14:41:54,424] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:54,425] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:54,459] [INFO] [Airline Passenger Reviews Logger] [370800297] :  97.53%	  94.17%	  96.18%		 96.45%
# [2024-02-15 14:41:54,460] [INFO] [Airline Passenger Reviews Logger] [370800297] :                    *** Validation Dataset ***
# [2024-02-15 14:41:54,461] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:54,462] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:54,489] [INFO] [Airline Passenger Reviews Logger] [370800297] :  97.56%	  94.00%	  96.10%		 96.37%
#
# [2024-02-15 14:41:54,499] [INFO] [Airline Passenger Reviews Logger] [370800297] :               >>>>> Decision Tree Classifier <<<<<
# [2024-02-15 14:41:54,499] [INFO] [Airline Passenger Reviews Logger] [370800297] :                       *** Test Dataset ***
# [2024-02-15 14:41:54,506] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:54,506] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:54,536] [INFO] [Airline Passenger Reviews Logger] [370800297] :  93.22%	  93.91%	  94.35%		 94.41%
# [2024-02-15 14:41:54,537] [INFO] [Airline Passenger Reviews Logger] [370800297] :                    *** Validation Dataset ***
# [2024-02-15 14:41:54,538] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:54,538] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:54,556] [INFO] [Airline Passenger Reviews Logger] [370800297] :  93.62%	  93.83%	  94.46%		 94.54%
#
# [2024-02-15 14:41:54,659] [INFO] [Airline Passenger Reviews Logger] [370800297] :             >>>>> Gradient Boosting Classifier <<<<<
# [2024-02-15 14:41:54,660] [INFO] [Airline Passenger Reviews Logger] [370800297] :                       *** Test Dataset ***
# [2024-02-15 14:41:54,661] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:54,662] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:54,690] [INFO] [Airline Passenger Reviews Logger] [370800297] :  94.42%	  92.22%	  94.03%		 94.28%
# [2024-02-15 14:41:54,690] [INFO] [Airline Passenger Reviews Logger] [370800297] :                    *** Validation Dataset ***
# [2024-02-15 14:41:54,692] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:54,693] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:54,710] [INFO] [Airline Passenger Reviews Logger] [370800297] :  94.42%	  92.09%	  93.95%		 94.20%
#
# [2024-02-15 14:41:54,718] [INFO] [Airline Passenger Reviews Logger] [370800297] :                   >>>>> Gradient Descent <<<<<
# [2024-02-15 14:41:54,718] [INFO] [Airline Passenger Reviews Logger] [370800297] :                       *** Test Dataset ***
# [2024-02-15 14:41:54,719] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:54,720] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:54,752] [INFO] [Airline Passenger Reviews Logger] [370800297] :  88.38%	  81.67%	  86.74%		 87.43%
# [2024-02-15 14:41:54,753] [INFO] [Airline Passenger Reviews Logger] [370800297] :                    *** Validation Dataset ***
# [2024-02-15 14:41:54,753] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:54,754] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:54,779] [INFO] [Airline Passenger Reviews Logger] [370800297] :  88.42%	  81.28%	  86.55%		 87.24%
#
# [2024-02-15 14:41:58,850] [INFO] [Airline Passenger Reviews Logger] [370800297] :                >>>>> KNeighbors Classifier <<<<<
# [2024-02-15 14:41:58,851] [INFO] [Airline Passenger Reviews Logger] [370800297] :                       *** Test Dataset ***
# [2024-02-15 14:41:58,851] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:58,852] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:58,880] [INFO] [Airline Passenger Reviews Logger] [370800297] :  94.48%	  88.76%	  92.40%		 92.90%
# [2024-02-15 14:41:58,880] [INFO] [Airline Passenger Reviews Logger] [370800297] :                    *** Validation Dataset ***
# [2024-02-15 14:41:58,881] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:58,881] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:58,901] [INFO] [Airline Passenger Reviews Logger] [370800297] :  94.40%	  88.06%	  92.02%		 92.54%
#
# [2024-02-15 14:41:59,025] [INFO] [Airline Passenger Reviews Logger] [370800297] :                       >>>>> Lightgbm <<<<<
# [2024-02-15 14:41:59,026] [INFO] [Airline Passenger Reviews Logger] [370800297] :                       *** Test Dataset ***
# [2024-02-15 14:41:59,027] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:59,027] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:59,071] [INFO] [Airline Passenger Reviews Logger] [370800297] :  97.53%	  94.17%	  96.18%		 96.45%
# [2024-02-15 14:41:59,072] [INFO] [Airline Passenger Reviews Logger] [370800297] :                    *** Validation Dataset ***
# [2024-02-15 14:41:59,072] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:59,073] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:59,099] [INFO] [Airline Passenger Reviews Logger] [370800297] :  97.56%	  94.00%	  96.10%		 96.37%
#
# [2024-02-15 14:41:59,105] [INFO] [Airline Passenger Reviews Logger] [370800297] :                 >>>>> Logistic Regression <<<<<
# [2024-02-15 14:41:59,105] [INFO] [Airline Passenger Reviews Logger] [370800297] :                       *** Test Dataset ***
# [2024-02-15 14:41:59,106] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:59,107] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:59,143] [INFO] [Airline Passenger Reviews Logger] [370800297] :  86.63%	  83.40%	  86.79%		 87.25%
# [2024-02-15 14:41:59,144] [INFO] [Airline Passenger Reviews Logger] [370800297] :                    *** Validation Dataset ***
# [2024-02-15 14:41:59,144] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:59,144] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:59,162] [INFO] [Airline Passenger Reviews Logger] [370800297] :  86.87%	  83.25%	  86.79%		 87.25%
#
# [2024-02-15 14:41:59,190] [INFO] [Airline Passenger Reviews Logger] [370800297] :                     >>>>> Naive Bayes <<<<<
# [2024-02-15 14:41:59,191] [INFO] [Airline Passenger Reviews Logger] [370800297] :                       *** Test Dataset ***
# [2024-02-15 14:41:59,192] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:59,193] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:59,218] [INFO] [Airline Passenger Reviews Logger] [370800297] :  82.88%	  81.40%	  84.29%		 84.68%
# [2024-02-15 14:41:59,219] [INFO] [Airline Passenger Reviews Logger] [370800297] :                    *** Validation Dataset ***
# [2024-02-15 14:41:59,219] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:41:59,220] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:41:59,239] [INFO] [Airline Passenger Reviews Logger] [370800297] :  83.20%	  81.36%	  84.37%		 84.76%
#
# [2024-02-15 14:42:00,029] [INFO] [Airline Passenger Reviews Logger] [370800297] :               >>>>> Random Forest Classifier <<<<<
# [2024-02-15 14:42:00,030] [INFO] [Airline Passenger Reviews Logger] [370800297] :                       *** Test Dataset ***
# [2024-02-15 14:42:00,030] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:42:00,031] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:42:00,058] [INFO] [Airline Passenger Reviews Logger] [370800297] :  97.01%	  94.19%	  95.99%		 96.23%
# [2024-02-15 14:42:00,059] [INFO] [Airline Passenger Reviews Logger] [370800297] :                    *** Validation Dataset ***
# [2024-02-15 14:42:00,060] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:42:00,060] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:42:00,079] [INFO] [Airline Passenger Reviews Logger] [370800297] :  96.89%	  94.08%	  95.88%		 96.12%
#
# [2024-02-15 14:42:43,374] [INFO] [Airline Passenger Reviews Logger] [370800297] :                >>>>> Support Vector Machine <<<<<
# [2024-02-15 14:42:43,374] [INFO] [Airline Passenger Reviews Logger] [370800297] :                       *** Test Dataset ***
# [2024-02-15 14:42:43,374] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:42:43,374] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:42:43,405] [INFO] [Airline Passenger Reviews Logger] [370800297] :  95.45%	  93.33%	  94.97%		 95.19%
# [2024-02-15 14:42:43,405] [INFO] [Airline Passenger Reviews Logger] [370800297] :                    *** Validation Dataset ***
# [2024-02-15 14:42:43,406] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:42:43,407] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:42:43,424] [INFO] [Airline Passenger Reviews Logger] [370800297] :  95.56%	  93.06%	  94.87%		 95.11%
#
# [2024-02-15 14:42:43,470] [INFO] [Airline Passenger Reviews Logger] [370800297] :                  >>>>> Xgboost Classifier <<<<<
# [2024-02-15 14:42:43,471] [INFO] [Airline Passenger Reviews Logger] [370800297] :                       *** Test Dataset ***
# [2024-02-15 14:42:43,473] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:42:43,473] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:42:43,512] [INFO] [Airline Passenger Reviews Logger] [370800297] :  97.04%	  94.51%	  96.16%		 96.38%
# [2024-02-15 14:42:43,513] [INFO] [Airline Passenger Reviews Logger] [370800297] :                    *** Validation Dataset ***
# [2024-02-15 14:42:43,514] [INFO] [Airline Passenger Reviews Logger] [370800297] :  Precision 	 Recall 	ROC-AUC Score 	  Accuracy Score
# [2024-02-15 14:42:43,515] [INFO] [Airline Passenger Reviews Logger] [370800297] : ----------------------------------------------------------------
# [2024-02-15 14:42:43,548] [INFO] [Airline Passenger Reviews Logger] [370800297] :  97.18%	  94.13%	  96.01%		 96.26%
#
# [2024-02-15 14:42:43,549] [INFO] [Airline Passenger Reviews Logger] [370800297] : Model: Best_model.joblib with a best Accuracy Score : 96.41%
# [2024-02-15 14:42:43,551] [INFO] [Airline Passenger Reviews Logger] [common] : json file saved at : artifacts\model_evaluation\metrics.json
# [2024-02-15 14:42:43,553] [INFO] [Airline Passenger Reviews Logger] [370800297] : Best model: Best_model.joblib saved as 'Best_model'.joblib file format
